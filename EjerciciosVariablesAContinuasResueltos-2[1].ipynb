# %% [markdown]
# # Índice
#
#  - [Teoria](#teoría)
#  - [Teoria Respondida ](#teoria-respondida)
#  - [Ejercicios](#ejercicios)
#
# 1. [Ejercicio 1](EjerciciosVariablesAContinuasResueltos-2.ipynb#ejercicio-3)
# 2. [Ejercicio 2](#ejercicio-2)
# 3. [Ejercicio 3](#ejercicio-3)
# 4. [Ejercicio 4](#ejercicio-4)
# 5. [Ejercicio 5](#ejercicio-5)
# 6. [Ejercicio 6](#ejercicio-6)
# 7. [Ejercicio 7](#ejercicio-7)
# 8. [Ejercicio 8](#ejercicio-8)
# 9. [Ejercicio 9](#ejercicio-9)
# 10. [Ejercicio 10](#ejercicio-10)
# 11. [Ejercicio 11](#ejercicio-11)
# 12. [Ejercicio 12](#ejercicio-12)
# 13. [Ejercicio 13](#ejercicio-13)
# 14. [Ejercicio 14](#ejercicio-14)
# 15. [Ejercicio 15](#ejercicio-15)
# 16. [Ejercicio 16](#ejercicio-16)
# 17. [Ejercicio 17](#ejercicio-17)

# %% [markdown]
# # Ejercicios de Variables Aleatorias Continuas #

# %% [markdown]
# ## Teoría

# %% [markdown]
# ### 1. Subraya la opción correcta:
#
# a) Una distribución normal es (simétrica, asimétrica) respecto a la media.
#
#
# b) La distribución normal estándar tiene media de (0, 1) y desviación estándar de (0, 1).
#
#
# c) La P(Z ≤ 0) es (1, 0.5).
#
#
# d) Los puntos de inflexión de una distribución normal se encuentran a (+/−2, +/−1) desviaciones estándar.
#
#
# e) El proceso de cambiar la variable aleatoria X por $Z = \frac{X - \mu}{\sigma}$ se llama (transformación, estandarización).
#
#
# f) En el punto máximo de una distribución normal se cumple que (media = moda = mediana, media ≠ moda ≠ mediana).
#
#
# g) Si Z es una variable aleatoria con distribución normal estándar, entonces P(−2 < Z < 2) es aproximadamente igual a (0.99, 0.95, 0.68).
#
#
# h) Si se transforma una distribución normal en una distribución normal estándar, entonces lo que no cambia es (la media, la forma, la varianza).
#
#
# i) Si la probabilidad es menor a 0.5, entonces el valor de Z es (negativo, positivo).
#
#
# j) En una distribución normal, si la variable aleatoria X tiene un valor positivo muy grande, entonces tiene una (mayor, menor) probabilidad de ocurrir.

# %% [markdown]
# ## Teoria respondida
#
# a) Una distribución normal es **simétrica** respecto a la media.
#
#
# b) La distribución normal estándar tiene media de **0** y desviación estándar de **1**.
#
#
# c) La P(Z ≤ 0) es **0.5**.
#
#
# d) Los puntos de inflexión de una distribución normal se encuentran a **+/−1** desviaciones estándar.
#
#
# e) El proceso de cambiar la variable aleatoria X por $Z = \frac{X - \mu}{\sigma}$ se llama **estandarización**.
#
#
# f) En el punto máximo de una distribución normal se cumple que **media = moda = mediana**.
#
#
# g) Si Z es una variable aleatoria con distribución normal estándar, entonces P(−2 < Z < 2) es aproximadamente igual a **0.95**.
#
#
# h) Si se transforma una distribución normal en una distribución normal estándar, entonces lo que no cambia es **la forma**.
#
#
# i) Si la probabilidad es menor a 0.5, entonces el valor de Z es **negativo**.
#
#
# j) En una distribución normal, si la variable aleatoria X tiene un valor positivo muy grande, entonces tiene una **menor** probabilidad de ocurrir.

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# De acuerdo con el artículo “Otra vez la educación”, de Alejandro Villagómez (Villagómez, 2010), un tema recurrente en la agenda nacional es la educación, debido a los malos resultados obtenidos en pruebas tipo enlace (Evaluación Nacional del Logro Académico en Centros Escolares) o pisa (Programa Internacional para la Evaluación del Estudiante). Según un estudio realizado por la ocde (Organización para la Cooperación y el Desarrollo Económico), existe un vínculo entre las habilidades cognitivas reflejadas en la prueba de pisa y el crecimiento económico, es decir, “se estimaba la ganancia que se obtendría por mayor crecimiento, en términos del pib actual, esto es, la ganancia en valor presente”. De acuerdo con los resultados obtenidos en la prueba de pisa, México ocupa los últimos lugares junto con países como Turquía.
#
# En palabras de Alejandro Villagómez: Considerando el escenario más moderado (y probablemente realista) que fue suponer reformas en 2010 que permitan aumentar el puntaje promedio en 25 puntos pisa hacia 2030, se estimaba que la ganancia (en valor presente) para México por un mayor crecimiento sería equivalente a 268% del pib actual. Este valor podría superar el 2000% en el escenario más demandante.
#
# También hace unos días hice referencia en mi blog a otro estudio que se enfocaba en el área de matemáticas utilizando resultados pisa y analizaba la situación en las colas de la distribución, es decir, considerando a nuestros mejores estudiantes en comparación con los de otros países.
# Sin entrar en detalles, sólo menciono que el estudio utilizaba como referencia un puntaje de 650 que coloca a un estudiante en el 10% superior de la ocde.
#
# Por cierto, la media mexicana fue de 405, pero el punto es que con esta referencia de 650 tendríamos que sólo tres de cada mil estudiantes mexicanos se ubicarían en este círculo exclusivo que es el 10% superior entre los países de la ocde.
#
# ### Ejercicio 2:
#
# a) Se sabe que las calificaciones o puntajes de evaluaciones siguen una distribución normal.
# De acuerdo con los datos proporcionados en el fragmento anterior, ¿cuál es la desviación estándar mexicana?
#
# b) ¿Cuáles son los puntajes en los que se encuentra el 90% central de los estudiantes mexicanos?

# %% [markdown]
# ### Para resolver este ejercicio:
#
# a) Calcular la desviación estándar mexicana:
#
# Sabemos que:
#
# - La media (𝜇) mexicana es 405.
#
# - Para que un puntaje de 650 esté en el 10% superior de la distribución
# (𝑃(𝑋>650)=0.10), necesitamos calcular la desviación estándar (𝜎).
#
# La fórmula de estandarización de la distribución normal es:
#
# $$Z = \frac{X - \mu}{\sigma}$$
#
# Usamos la función inversa de la distribución normal estándar para encontrar 𝑍, y luego resolvemos para 𝜎.
#
# ---
#
# b) Calcular los puntajes del 90% central:
#
# - El 90% central corresponde al rango de puntajes entre el percentil 5 y el percentil 95. Esto significa que:
#
# $$P(X \leq X_{\text{inferior}}) = 0.05 \quad \text{y} \quad P(X \leq X_{\text{superior}}) = 0.95$$
#
# Calculamos los límites usando la desviación estándar obtenida.

# %%
from scipy.stats import norm

# Datos
media_mexicana = 405  # Media mexicana
puntaje_superior = 650  # Puntaje del 10% superior
prob_superior = 0.10  # Probabilidad del 10% superior

z_superior = norm.ppf(1 - prob_superior)

desviacion_estandar = (puntaje_superior - media_mexicana) / z_superior

print(f"a) Desviación estándar mexicana: {desviacion_estandar:.2f}")

z_inferior = norm.ppf(0.05)
z_superior = norm.ppf(0.95)

puntaje_inferior = media_mexicana + z_inferior * desviacion_estandar
puntaje_superior = media_mexicana + z_superior * desviacion_estandar
print(f"b) Rango del 90% central de estudiantes mexicanos: {puntaje_inferior:.2f} a {puntaje_superior:.2f}")
# Out:
# a) Desviación estándar mexicana: 191.17
# b) Rango del 90% central de estudiantes mexicanos: 90.55 a 719.45

# %% [markdown]
# ### Ejercicio 3:
# Como vimos en este bloque, el área bajo la curva de una función se traduce en la probabilidad entre dos valores. Calcula las integrales definidas siguientes:

# %% [markdown]
# a) $\int_{1}^{1.5} (2x + 1) \, dx$
#
# b) $\int_{0}^{0.5} \frac{x^2}{3} \, dx$
#
# c) $\int_{1}^{1.2} e^x \, dx$
#
# d) $\int_{\frac{\pi}{6}}^{\frac{\pi}{4}} \sin x \, dx$

# %% [markdown]
# #### a)
# $\int_{1}^{1.5} (2x + 1) \, dx$}
# \begin{align*}
# \text{Antiderivada: } & \int (2x + 1) \, dx = x^2 + x + C \\
# \text{Evaluamos: } & F(1.5) = (1.5)^2 + (1.5) = 2.25 + 1.5 = 3.75 \\
#                    & F(1) = (1)^2 + (1) = 1 + 1 = 2 \\
# \text{Integral: } & \int_{1}^{1.5} (2x + 1) \, dx = F(1.5) - F(1) = 3.75 - 2 = 1.75
# \end{align*}
#
# #### b)
# $\int_{0}^{0.5} \frac{x^2}{3} \, dx$}
# \begin{align*}
# \text{Antiderivada: } & \int \frac{x^2}{3} \, dx = \frac{x^3}{9} + C \\
# \text{Evaluamos: } & F(0.5) = \frac{(0.5)^3}{9} = \frac{0.125}{9} = \frac{1}{72} \\
#                    & F(0) = 0 \\
# \text{Integral: } & \int_{0}^{0.5} \frac{x^2}{3} \, dx = F(0.5) - F(0) = \frac{1}{72} - 0 = \frac{1}{72}
# \end{align*}
#
# #### c)
# $\int_{1}^{1.2} e^x \, dx$}
# \begin{align*}
# \text{Antiderivada: } & \int e^x \, dx = e^x + C \\
# \text{Evaluamos: } & F(1.2) = e^{1.2} \\
#                    & F(1) = e^1 \\
# \text{Integral: } & \int_{1}^{1.2} e^x \, dx = F(1.2) - F(1) = e^{1.2} - e
# \end{align*}
#
# #### d)
# $\int_{\frac{\pi}{6}}^{\frac{\pi}{4}} \sin x \, dx$}
# \begin{align*}
# \text{Antiderivada: } & \int \sin x \, dx = -\cos x + C \\
# \text{Evaluamos: } & F\left(\frac{\pi}{4}\right) = -\cos\left(\frac{\pi}{4}\right) = -\frac{\sqrt{2}}{2} \\
#                    & F\left(\frac{\pi}{6}\right) = -\cos\left(\frac{\pi}{6}\right) = -\frac{\sqrt{3}}{2} \\
# \text{Integral: } & \int_{\frac{\pi}{6}}^{\frac{\pi}{4}} \sin x \, dx = F\left(\frac{\pi}{4}\right) - F\left(\frac{\pi}{6}\right) = -\frac{\sqrt{2}}{2} + \frac{\sqrt{3}}{2}
# \end{align*}

# %%
import sympy as sp

x = sp.Symbol('x')

integral_a = sp.integrate(2 * x + 1, (x, 1, 1.5))

integral_b = sp.integrate(x**2 / 3, (x, 0, 0.5))

integral_c = sp.integrate(sp.exp(x), (x, 1, 1.2))

integral_d = sp.integrate(sp.sin(x), (x, sp.pi / 6, sp.pi / 4))

print(f"a) Integral de (2x + 1) dx desde 1 a 1.5: {integral_a}")
print(f"b) Integral de (x^2 / 3) dx desde 0 a 0.5: {integral_b}")
print(f"c) Integral de e^x dx desde 1 a 1.2: {integral_c.evalf()}")
print(f"d) Integral de sen(x) dx desde π/6 a π/4: {integral_d.evalf()}")
# Out:
# a) Integral de (2x + 1) dx desde 1 a 1.5: 1.75000000000000
# b) Integral de (x^2 / 3) dx desde 0 a 0.5: 0.0138888888888889
# c) Integral de e^x dx desde 1 a 1.2: 0.601835094277502
# d) Integral de sen(x) dx desde π/6 a π/4: 0.158918622597891

# %% [markdown]
# ### Ejercicio 4:
#
# Sea Z una variable aleatoria que tiene una distribución normal estándar; encuentra:
#
# a) P(Z ≤ 1.54)
#
# b) P(Z > 1.54)
#
# c) P(−0.1 ≤ Z ≤ 0.9)
#
# d) P(−3.66 ≤ Z ≤ −2.15)

# %% [markdown]
# Sea \( Z \) una variable aleatoria que tiene una distribución normal estándar; encuentra:
#
# ####  a)   P(Z ≤ 1.54)
#
# \begin{align*}
# \text{Utilizando la tabla de la distribución normal estándar, encontramos:} & \\
# P(Z \leq 1.54) & \approx 0.9382
# \end{align*}
#
#
# ####  b) P( Z > 1.54)
#
# \begin{align*}
# P(Z > 1.54) & = 1 - P(Z \leq 1.54) \\
#              & \approx 1 - 0.9382 = 0.0618
# \end{align*}
#
#
# ####  c) P(−0.1 ≤ Z ≤ 0.9)
#
# \begin{align*}
# P(-0.1 \leq Z \leq 0.9) & = P(Z \leq 0.9) - P(Z \leq -0.1) \\
# \text{Buscamos estos valores:} & \\
# P(Z \leq 0.9) & \approx 0.8159 \\
# P(Z \leq -0.1) & \approx 0.4602 \\
# P(-0.1 \leq Z \leq 0.9) & \approx 0.8159 - 0.4602 = 0.3557
# \end{align*}
#
#
# ####  d) P(−3.66 ≤ Z ≤ −2.15)
#
# \begin{align*}
# P(-3.66 \leq Z \leq -2.15) & = P(Z \leq -2.15) - P(Z \leq -3.66) \\
# \text{Buscamos estos valores:} & \\
# P(Z \leq -2.15) & \approx 0.0158 \\
# P(Z \leq -3.66) & \approx 0.0001 \\
# P(-3.66 \leq Z \leq -2.15) & \approx 0.0158 - 0.0001 = 0.0157
# \end{align*}

# %%
from scipy.stats import norm

p_a = norm.cdf(1.54)

p_b = 1 - norm.cdf(1.54)

p_c = norm.cdf(0.9) - norm.cdf(-0.1)

p_d = norm.cdf(-2.15) - norm.cdf(-3.66)

print(f"a) P(Z ≤ 1.54): {p_a:.4f}")
print(f"b) P(Z > 1.54): {p_b:.4f}")
print(f"c) P(−0.1 ≤ Z ≤ 0.9): {p_c:.4f}")
print(f"d) P(−3.66 ≤ Z ≤ −2.15): {p_d:.4f}")
# Out:
# a) P(Z ≤ 1.54): 0.9382
# b) P(Z > 1.54): 0.0618
# c) P(−0.1 ≤ Z ≤ 0.9): 0.3558
# d) P(−3.66 ≤ Z ≤ −2.15): 0.0157

# %% [markdown]
# ### Ejercicio 5:
#
# Determina el valor z:
#
# a) P(Z ≤ z) = 0.6293
#
# b) P(−z ≤ Z ≤ +z) = 0.90
#
# c) P(−z ≤ Z ≤ +z) = 0.95
#
# d) P(−z ≤ Z ≤ +z) = 0.99

# %% [markdown]
# Determina el valor \( z \):
#
# #### a) P(Z ≤ z)= 0.6293
#
# \begin{align*}
# \text{Buscando en la tabla de la distribución normal estándar, encontramos:} & \\
# z & \approx 0.32
# \end{align*}
#
# #### b) P(−z ≤ Z ≤ +z)= 0.90
#
# \begin{align*}
# P(Z \leq z) - P(Z \leq -z) & = 0.90 \\
# P(Z \leq z) & = 0.95 \\
# z & \approx 1.645
# \end{align*}
#
# #### c) P( −z ≤ Z ≤ +z)= 0.95
#
# \begin{align*}
# P(Z \leq z) - P(Z \leq -z) & = 0.95 \\
# P(Z \leq z) & = 0.975 \\
# z & \approx 1.96
# \end{align*}
#
# #### d) P(−z ≤ Z ≤ +z)= 0.99
#
# \begin{align*}
# P(Z \leq z) - P(Z \leq -z) & = 0.99 \\
# P(Z \leq z) & = 0.995 \\
# z & \approx 2.576
# \end{align*}

# %%
from scipy.stats import norm

z_a = norm.ppf(0.6293)


z_b = norm.ppf((1 + 0.90) / 2)

z_c = norm.ppf((1 + 0.95) / 2)

z_d = norm.ppf((1 + 0.99) / 2)

print(f"a) z tal que P(Z ≤ z) = 0.6293: {z_a:.4f}")
print(f"b) z tal que P(−z ≤ Z ≤ +z) = 0.90: ±{z_b:.4f}")
print(f"c) z tal que P(−z ≤ Z ≤ +z) = 0.95: ±{z_c:.4f}")
print(f"d) z tal que P(−z ≤ Z ≤ +z) = 0.99: ±{z_d:.4f}")
# Out:
# a) z tal que P(Z ≤ z) = 0.6293: 0.3300
# b) z tal que P(−z ≤ Z ≤ +z) = 0.90: ±1.6449
# c) z tal que P(−z ≤ Z ≤ +z) = 0.95: ±1.9600
# d) z tal que P(−z ≤ Z ≤ +z) = 0.99: ±2.5758

# %% [markdown]
# ### Ejercicio 6:
# Sea X una variable aleatoria que se distribuye de manera normal con μ = 4 y σ = 1.5. Calcula:
#
# a) P(X ≤ 5)
#
# b) P(X ≥ 4.5)
#
# c) P(0 ≤ X ≤ 2)

# %% [markdown]
# Sea \( X \) una variable aleatoria que se distribuye de manera normal con \( \mu = 4 \) y \( \sigma = 1.5 \). Calcula:
#
# #### a) P(X ≤ 5)
#
# \begin{align*}
# Z & = \frac{5 - 4}{1.5} \approx 0.67 \\
# \text{Buscando en la tabla de la distribución normal estándar, encontramos:} & \\
# P(Z \leq 0.67) & \approx 0.7486
# \end{align*}
#
# #### b) P(X ≥ 4.5)
#
# \begin{align*}
# Z & = \frac{4.5 - 4}{1.5} \approx 0.33 \\
# P(X \geq 4.5) & = 1 - P(Z \leq 0.33) \approx 1 - 0.6293 \approx 0.3707
# \end{align*}
#
# #### c) P(0 ≤ X ≤ 2)
#
# \begin{align*}
# Z_0 & = \frac{0 - 4}{1.5} \approx -2.67 \\
# Z_2 & = \frac{2 - 4}{1.5} \approx -1.33 \\
# P(0 \leq X \leq 2) & = P(Z \leq -1.33) - P(Z \leq -2.67) \\
# P(Z \leq -1.33) & \approx 0.0918 \\
# P(Z \leq -2.67) & \approx 0.0038 \\
# P(0 \leq X \leq 2) & \approx 0.0918 - 0.0038 \approx 0.0880
# \end{align*}

# %%
from scipy.stats import norm

mu = 4 
sigma = 1.5

p_a = norm.cdf(5, loc=mu, scale=sigma)

p_b = 1 - norm.cdf(4.5, loc=mu, scale=sigma)

p_c = norm.cdf(2, loc=mu, scale=sigma) - norm.cdf(0, loc=mu, scale=sigma)

# Imprimir resultados
print(f"a) P(X ≤ 5): {p_a:.4f}")
print(f"b) P(X ≥ 4.5): {p_b:.4f}")
print(f"c) P(0 ≤ X ≤ 2): {p_c:.4f}")
# Out:
# a) P(X ≤ 5): 0.7475
# b) P(X ≥ 4.5): 0.3694
# c) P(0 ≤ X ≤ 2): 0.0874

# %% [markdown]
# ### Ejercicio 7:
# De acuerdo con la Organización de Naciones Unidas (onu), en Latinoamérica se tiene una esperanza de vida al nacer de 73.4 años y una desviación estándar de 4.3714 años.
#
# Si la esperanza de vida de una persona sigue una distribución normal, calcula:
#
# a) La probabilidad de que una persona sobrepase los 80 años de vida.
#
# b) La probabilidad de que una persona al nacer tenga una esperanza de vida entre 70 y 75 años.
#
# c) ¿A partir de qué valor se tiene el 10% más alto de la esperanza de vida al nacer?

# %% [markdown]
# #### a) La probabilidad de que una persona sobrepase los 80 años de vida.
#
# \begin{align*}
# Z & = \frac{80 - 73.4}{4.3714} \approx 1.5 \\
# P(X > 80) & = 1 - P(Z \leq 1.5) \\
# & \approx 1 - 0.9332 \approx 0.0668
# \end{align*}
#
# #### b) La probabilidad de que una persona al nacer tenga una esperanza de vida entre 70 y 75 años.
#
# \begin{align*}
# Z_{70} & = \frac{70 - 73.4}{4.3714} \approx -0.78 \\
# Z_{75} & = \frac{75 - 73.4}{4.3714} \approx 0.36 \\
# P(70 < X < 75) & = P(Z \leq 0.36) - P(Z \leq -0.78) \\
# & \approx 0.6406 - 0.2177 \approx 0.4229
# \end{align*}
#
# #### c) ¿A partir de qué valor se tiene el 10\% más alto de la esperanza de vida al nacer?
#
# Para encontrar el percentil 90:
#
# \begin{align*}
# P(Z \leq z) & = 0.90 \\
# z & \approx 1.2816 \\
# X & = \mu + z \cdot \sigma \\
# & = 73.4 + 1.2816 \cdot 4.3714 \approx 77.47
# \end{align*}

# %% [markdown]
# ### Para resolver este ejercicio:
#
# Datos del problema:
#
# - Media (𝜇) = 73.4 años.
# - Desviación estándar (𝜎) = 4.3714 años.
#
# Fórmulas clave:
#
# - La probabilidad acumulada se calcula como 𝑃(𝑋≤𝑥) usando la función acumulada de la normal.
#
# - Usamos la fórmula de estandarización
#
# $$Z = \frac{X - \mu}{\sigma}$$

# %%
from scipy.stats import norm

mu = 73.4  # esperanza de vida (media)
sigma = 4.3714  # desviación estándar

p_a = 1 - norm.cdf(80, loc=mu, scale=sigma)

p_b = norm.cdf(75, loc=mu, scale=sigma) - norm.cdf(70, loc=mu, scale=sigma)

percentile_90 = norm.ppf(0.9, loc=mu, scale=sigma)

# Imprimir resultados
print(f"a) P(X > 80): {p_a:.4f}")
print(f"b) P(70 ≤ X ≤ 75): {p_b:.4f}")
print(f"c) Valor para el 10% más alto de la esperanza de vida: {percentile_90:.2f} años")
# Out:
# a) P(X > 80): 0.0655
# b) P(70 ≤ X ≤ 75): 0.4245
# c) Valor para el 10% más alto de la esperanza de vida: 79.00 años

# %% [markdown]
# ### Ejercicio 8:
#
# Entre mayo y junio de 2011, la cotización del dólar a la venta tuvo una media de $16.9205 y una desviación estándar de $0.2695. Si la cotización del dólar sigue una distribución normal, determina:
#
# a) La probabilidad de que la venta de un dólar sobrepase los $18.
#
# b) La probabilidad de que la cotización del dólar a la venta sea menor a los $15.

# %% [markdown]
# #### a) La probabilidad de que la venta de un dólar sobrepase los $18.
#
# \begin{align*}
# Z & = \frac{18 - 16.9205}{0.2695} \approx 4.008 \\
# P(X > 18) & = 1 - P(Z \leq 4.008) \\
# & \approx 1 - 0.9999 \approx 0.0001
# \end{align*}
#
# #### b) La probabilidad de que la cotización del dólar a la venta sea menor a los $15.
#
# \begin{align*}
# Z & = \frac{15 - 16.9205}{0.2695} \approx -7.12 \\
# P(X < 15) & = P(Z \leq -7.12) \\
# & \approx 0.0000
# \end{align*}

# %% [markdown]
# ### Para resolver este ejercicio:
#
# Datos del problema:
#
# - Media (𝜇) = 16.9205.
#
# - Desviación estándar (𝜎) = 0.2695.
#
# Fórmulas clave:
#
# - Para calcular 𝑃(𝑋≤𝑥), usamos la función acumulada de la distribución normal: norm.cdf(x, loc=μ, scale=σ).
#
#
# - Para probabilidades de tipo 𝑃(𝑋>𝑥), usamos la relación complementaria:
# 𝑃(𝑋>𝑥)=1−𝑃(𝑋≤𝑥).

# %%
from scipy.stats import norm

mu = 16.9205  # Media
sigma = 0.2695  # Desviación estándar

p_a = 1 - norm.cdf(18, loc=mu, scale=sigma)

p_b = norm.cdf(15, loc=mu, scale=sigma)

print(f"a) P(X > 18): {p_a:.4f}")
print(f"b) P(X < 15): {p_b:.4f}")
# Out:
# a) P(X > 18): 0.0000
# b) P(X < 15): 0.0000

# %% [markdown]
# ### Ejercicio 9:
#
# Uno de los graves problemas que se enfrentan actualmente es la falta de agua y la
# contaminación de los acuíferos.
#
# De acuerdo con cifras de la semarnat (Secretaría del Medio Ambiente y Recursos Naturales) a través de conagua (Estadísticas del Agua en México, 2010,
# México, 2010), de 2002 a 2008 en el país las descargas residuales tuvieron una media de $7.795 \, \text{km}^3$/año
# con una desviación estándar de $0.2311 \, \text{km}^3$/año ($1 \, \text{km}^3$ equivale a mil millones de metros cúbicos).
#
# Suponiendo que las descargas residuales se distribuyen normalmente, encuentra la probabilidad de que, en un año, las descargas residuales sean:
#
# a) Menores a $7.5 \, \text{km}^3$
#
# b) Estén entre 7.5 y $7.9 \, \text{km}^3$
#
# c) ¿A partir de qué valor se tiene el 10% más bajo de descargas residuales?

# %% [markdown]
# #### a) Menores a $7.75 \, \text{km}^3$
#
# \begin{align*}
# Z & = \frac{7.5 - 7.795}{0.2311} \approx -1.27 \\
# P(X < 7.5) & = P(Z \leq -1.27) \\
# & \approx 0.1020
# \end{align*}
#
# #### b) Estén entre $7.5 \text{km}^3$ y $7.9 \text{km}^3$
#
# \begin{align*}
# Z_{7.5} & = \frac{7.5 - 7.795}{0.2311} \approx -1.27 \\
# Z_{7.9} & = \frac{7.9 - 7.795}{0.2311} \approx 0.45 \\
# P(7.5 < X < 7.9) & = P(Z \leq 0.45) - P(Z \leq -1.27) \\
# & \approx 0.6736 - 0.1020 \approx 0.5716
# \end{align*}
#
# #### c) ¿A partir de qué valor se tiene el 10\% más bajo de descargas residuales?
#
# Para encontrar el percentil 10:
#
# \begin{align*}
# P(Z \leq z) & = 0.10 \\
# z & \approx -1.2816 \\
# X & = \mu + z \cdot \sigma \\
# & = 7.795 + (-1.2816) \cdot 0.2311 \approx 7.57
# \end{align*}

# %% [markdown]
# ### Para resolver este problema:
#
# Datos del problema:
#
# - Media (𝜇) = $7.795 \, \text{km}^3$
#
# - Desviación estándar (𝜎) = $2.3 \, \text{km}^3$.
#
# Fórmulas clave:
#
# - Para calcular $$P(X \leq x)$$ usamos la función acumulada de la distribución normal: $$norm.cdf(x, loc=μ, scale=σ)$$.
#
# - Para calcular un intervalo $$P(a \leq X \leq b)$$
#
# usamos:$$P(a \leq X \leq b) = P(X \leq b) - P(X \leq a)$$
#
# Para encontrar el valor de 𝑋 que corresponde al percentil 10% $$(P(X \leq x)=0.1)$$
#
# usamos la función inversa acumulada: norm.ppf(prob, loc=μ, scale=σ).

# %%
from scipy.stats import norm

mu = 7.795  # Media
sigma = 0.2311  # Desviación estándar

p_a = norm.cdf(7.5, loc=mu, scale=sigma)

p_b = norm.cdf(7.9, loc=mu, scale=sigma) - norm.cdf(7.5, loc=mu, scale=sigma)

percentil_10 = norm.ppf(0.10, loc=mu, scale=sigma)

# Imprimir resultados
print(f"a) P(X < 7.5): {p_a:.4f}")
print(f"b) P(7.5 <= X <= 7.9): {p_b:.4f}")
print(f"c) Valor para el 10% más bajo: {percentil_10:.4f} km³")
# Out:
# a) P(X < 7.5): 0.1009
# b) P(7.5 <= X <= 7.9): 0.5743
# c) Valor para el 10% más bajo: 7.4988 km³

# %% [markdown]
# ### Ejercicio 10:
# De acuerdo con la Organización de Naciones Unidas (onu), los años de educación promedio son de 8.1 y una varianza de 3.1 en países latinoamericanos.
#
# Suponiendo que los años de educación promedio se distribuyen como una normal, calcula la probabilidad de que un país:
#
# a) Tenga más de 10 años de educación promedio.
#
# b) Tenga entre 7.5 y 10.5 años de educación promedio.
#
# c) ¿A partir de qué valor se tiene el 5% más bajo de educación?

# %% [markdown]
# #### a) Tenga más de 10 años de educación promedio.
#
# Primero, calculamos la desviación estándar:
#
# \[
# \sigma = \sqrt{3.1} \approx 1.76
# \]
#
# \begin{align*}
# Z & = \frac{10 - 8.1}{1.76} \approx 1.08 \\
# P(X > 10) & = 1 - P(Z \leq 1.08) \\
# & \approx 1 - 0.8599 \approx 0.1401
# \end{align*}
#
# #### b) Tenga entre 7.5 y 10.5 años de educación promedio.
#
# \begin{align*}
# Z_{7.5} & = \frac{7.5 - 8.1}{1.76} \approx -0.34 \\
# Z_{10.5} & = \frac{10.5 - 8.1}{1.76} \approx 1.37 \\
# P(7.5 < X < 10.5) & = P(Z \leq 1.37) - P(Z \leq -0.34) \\
# & \approx 0.9147 - 0.3669 \approx 0.5478
# \end{align*}
#
# #### c) ¿A partir de qué valor se tiene el 5\% más bajo de educación?
#
# Para encontrar el percentil 5:
#
# \begin{align*}
# P(Z \leq z) & = 0.05 \\
# z & \approx -1.645 \\
# X & = \mu + z \cdot \sigma \\
# & = 8.1 + (-1.645) \cdot 1.76 \approx 6.43
# \end{align*}

# %% [markdown]
# ### Pasos para resolver el ejercicio
#
# Media (𝜇) = 8.1 años.
#
# Varianza (𝜎2) = 3.1 → Desviación estándar (𝜎) = √3.1.
#
#
# Cálculo de probabilidades:
#
# a) Para $$P(X>10)$$
#
# usamos la función complementaria de la acumulada:
#
# $$ P(X>10)= 1 − P(X \leq 10) $$
#
# b) Para $$P(7.5≤X≤10.5)$$usamos:
#
# $$P(7.5≤X≤10.5)=P(X≤10.5)−P(X≤7.5)$$
#
# Percentil del 5%:
#
# Para calcular el valor 𝑋 del 5% más bajo $$P(X≤x)=0.05)$$
#  usamos la función inversa acumulada: $$X=norm.ppf(0.05,μ,σ)$$

# %%
from scipy.stats import norm
import math

mu = 8.1  # Media
sigma = math.sqrt(3.1)  # Desviación estándar

p_a = 1 - norm.cdf(10, loc=mu, scale=sigma)

p_b = norm.cdf(10.5, loc=mu, scale=sigma) - norm.cdf(7.5, loc=mu, scale=sigma)

percentil_5 = norm.ppf(0.05, loc=mu, scale=sigma)

print(f"a) P(X > 10): {p_a:.4f}")
print(f"b) P(7.5 <= X <= 10.5): {p_b:.4f}")
print(f"c) Valor para el 5% más bajo: {percentil_5:.4f} años")
# Out:
# a) P(X > 10): 0.1403
# b) P(7.5 <= X <= 10.5): 0.5469
# c) Valor para el 5% más bajo: 5.2039 años

# %% [markdown]
# ### Ejercicio 11:
#
# La industria petrolera es una de las principales fuentes de ingresos de países como Brasil, México, Venezuela y Arabia Saudita, entre otros. A continuación se presenta la producción de petróleo crudo de las 15 principales empresas en el mundo:

# %%
import pandas as pd

# Crear el DataFrame
datos = {
    "Principales empresas": [
        "Exxon Mobil Estados Unidos",
        "Sinopec China",
        "Royal Dutch Shell Reino Unido/Holanda",
        "PDVSA Venezuela",
        "CNPC China",
        "Conoco Phillips Estados Unidos",
        "Valero Energy Estados Unidos",
        "BP Reino Unido",
        "Total Francia",
        "Saudi Aramco Arabia Saudita",
        "Petrobras Brasil",
        "Chevron Estados Unidos",
        "NIOC Irán",
        "Petróleos Mexicanos México",
        "Nippon Japón",
    ],
    "Barriles diarios (miles)": [
        6271,
        4559,
        3639,
        3035,
        2913,
        2902,
        2780,
        2666,
        2594,
        2374,
        2161,
        2158,
        1566,
        1540,
        1317,
    ],
}

df = pd.DataFrame(datos)

# Mostrar el DataFrame
print(df)
# Out:
#                      Principales empresas  Barriles diarios (miles)
# 0              Exxon Mobil Estados Unidos                      6271
# 1                           Sinopec China                      4559
# 2   Royal Dutch Shell Reino Unido/Holanda                      3639
# 3                         PDVSA Venezuela                      3035
# 4                              CNPC China                      2913
# 5          Conoco Phillips Estados Unidos                      2902
# 6            Valero Energy Estados Unidos                      2780
# 7                          BP Reino Unido                      2666
# 8                           Total Francia                      2594
# 9             Saudi Aramco Arabia Saudita                      2374
# 10                       Petrobras Brasil                      2161
# 11                 Chevron Estados Unidos                      2158
# 12                              NIOC Irán                      1566
# ...

# %% [markdown]
# a) Determina la media y la desviación estándar poblacional.
# Con la información del inciso (a), y suponiendo que la producción de petróleo crudo se distribuye normalmente, calcula la probabilidad de que en un día, la producción de petróleo crudo:
#
# b) Sea mayor a 5500 barriles.
#
# c) Esté entre 2500 y 4000 barriles.
#
# d) ¿Cuántos barriles de petróleo crudo deben producirse en un día para que éste sea considerado “excelente”? Debe entenderse por “excelente” que esté en el 5% superior de la distribución.

# %% [markdown]
# ### Pasos para resolver el ejercicio:
#
# Producción de petróleo crudo en barriles diarios (miles):
#
# [6271,4559,3639,3035,2913,2902,2780,2666,2594,2374,2161,2158,1566,1540,1317]
#
# - Cálculo de la media (𝜇) y desviación estándar (𝜎)
#
# Media poblacional: $$\mu = \frac{\text{suma de datos}}{\text{número de datos}}$$
#
# ​Desviación estándar poblacional: $$\sigma = \sqrt{\frac{\sum_{i}(x_{i} - \mu)^2}{N}}$$
#
# - Probabilidades:
#
# b) Probabilidad de que la producción sea mayor a 5500:
#
# $$ P(X>5500)=1−P(X≤5500) $$
#
#
# c) Probabilidad de que la producción esté entre 2500 y 4000:
#
# $$P(2500≤X≤4000)=P(X≤4000)−P(X≤2500)$$
#
#
# Percentil del 95% (para el 5% superior):
#
# Determinamos el valor 𝑋 que corresponde al percentil 95:
#
# $$X=norm.ppf(0.95,μ,σ)$$
# ​

# %%
import numpy as np
from scipy.stats import norm

produccion = [6271, 4559, 3639, 3035, 2913, 2902, 2780, 2666, 2594, 2374, 2161, 2158, 1566, 1540, 1317]

media = np.mean(produccion)
desviacion_estandar = np.std(produccion, ddof=0)  # ddof=0 para desviación estándar poblacional

p_mayor_5500 = 1 - norm.cdf(5500, loc=media, scale=desviacion_estandar)

p_entre_2500_4000 = norm.cdf(4000, loc=media, scale=desviacion_estandar) - norm.cdf(2500, loc=media, scale=desviacion_estandar)

excelente = norm.ppf(0.95, loc=media, scale=desviacion_estandar)

print(f"a) Media: {media:.2f} miles de barriles")
print(f"   Desviación estándar: {desviacion_estandar:.2f} miles de barriles")
print(f"b) P(X > 5500): {p_mayor_5500:.4f}")
print(f"c) P(2500 <= X <= 4000): {p_entre_2500_4000:.4f}")
print(f"d) Producción para ser 'excelente': {excelente:.2f} miles de barriles")
# Out:
# a) Media: 2831.67 miles de barriles
#    Desviación estándar: 1218.79 miles de barriles
# b) P(X > 5500): 0.0143
# c) P(2500 <= X <= 4000): 0.4384
# d) Producción para ser 'excelente': 4836.39 miles de barriles

# %% [markdown]
# ### Ejercicio 12:
# Supongamos que la precipitación pluvial se distribuye normalmente. Observa la tabla siguiente:

# %%
import pandas as pd

# Crear el DataFrame
datos_precipitacion = {
    "Zona": [
        "Península de Baja California",
        "Noroeste",
        "Pacífico norte",
        "Balsas",
        "Pacífico sur",
        "Río Bravo",
        "Cuencas centrales norte",
        "Lerma Santiago Pacífico",
        "Golfo norte",
        "Golfo centro",
        "Frontera sur",
        "Península de Yucatán",
        "Aguas del Valle de México",
    ],
    "Precipitación (ml)": [
        168.3,
        448.1,
        747.7,
        963.0,
        1184.6,
        435.9,
        427.6,
        817.9,
        910.9,
        1552.8,
        1845.6,
        1219.2,
        610.2,
    ],
}

df_precipitacion = pd.DataFrame(datos_precipitacion)

# Mostrar el DataFrame
print(df_precipitacion)
# Out:
#                             Zona  Precipitación (ml)
# 0   Península de Baja California               168.3
# 1                       Noroeste               448.1
# 2                 Pacífico norte               747.7
# 3                         Balsas               963.0
# 4                   Pacífico sur              1184.6
# 5                      Río Bravo               435.9
# 6        Cuencas centrales norte               427.6
# 7        Lerma Santiago Pacífico               817.9
# 8                    Golfo norte               910.9
# 9                   Golfo centro              1552.8
# 10                  Frontera sur              1845.6
# 11          Península de Yucatán              1219.2
# 12     Aguas del Valle de México               610.2

# %% [markdown]
# Con esta información:
# a) Calcula la media y la desviación estándar poblacionales.
#
# b) Determina la probabilidad de que la precipitación pluvial sea mayor a 800 ml.
#
# c) ¿Cuál es la probabilidad de que la precipitación pluvial esté entre 500 y 1000 ml?
#
# d) Encuentra la cantidad de lluvia a partir de la cual se encuentra el 5% superior de la distribución (es decir, cantidad peligrosa de lluvia).

# %% [markdown]
# ### Pasos para resolver este ejercicio:
#
#
# - Cálculo de la media (𝜇) y desviación estándar (𝜎)
#
# Media poblacional: $$\mu = \frac{\text{suma de datos}}{\text{número de datos}}$$
#
# ​Desviación estándar poblacional: $$\sigma = \sqrt{\frac{\sum_{i}(x_{i} - \mu)^2}{N}}$$
#
# b) Probabilidad de que la precipitación pluvial sea mayor a 800 ml:
#
# $$P(X>800)=1−P(X≤800)$$
# c) Probabilidad de que la precipitación pluvial esté entre 500 y 1000 ml:
#
# $$P(500≤X≤1000)=P(X≤1000)−P(X≤500)$$
# 3. Valor para el 5% superior:
# Usamos la función inversa acumulada (norm.ppf) para encontrar el valor donde la cola superior tiene un 5%:
#
# $$X=norm.ppf(0.95,μ,σ)$$

# %%
import numpy as np
from scipy.stats import norm

precipitacion = [168.3, 448.1, 747.7, 963.0, 1184.6, 435.9, 427.6, 817.9, 910.9, 1552.8, 1845.6, 1219.2, 610.2]

media = np.mean(precipitacion)
desviacion_estandar = np.std(precipitacion, ddof=0)  

p_mayor_800 = 1 - norm.cdf(800, loc=media, scale=desviacion_estandar)

p_entre_500_1000 = norm.cdf(1000, loc=media, scale=desviacion_estandar) - norm.cdf(500, loc=media, scale=desviacion_estandar)

lluvia_peligrosa = norm.ppf(0.95, loc=media, scale=desviacion_estandar)

print(f"a) Media: {media:.2f} ml")
print(f"   Desviación estándar: {desviacion_estandar:.2f} ml")
print(f"b) P(X > 800): {p_mayor_800:.4f}")
print(f"c) P(500 <= X <= 1000): {p_entre_500_1000:.4f}")
print(f"d) Cantidad peligrosa de lluvia (5% superior): {lluvia_peligrosa:.2f} ml")
# Out:
# a) Media: 871.68 ml
#    Desviación estándar: 463.18 ml
# b) P(X > 800): 0.5615
# c) P(500 <= X <= 1000): 0.3980
# d) Cantidad peligrosa de lluvia (5% superior): 1633.53 ml

# %% [markdown]
# ### Ejercicio 13:
# La falta de sueño reparador puede afectar nuestra capacidad para llevar a cabo las actividades diarias, ya que estamos demasiado cansados o tenemos problemas de concentración.
#
# Todos los tipos de insomnio pueden llevar a somnolencia diurna, mala concentración e incapacidad para sentirnos renovados y descansados en la mañana.
#
# a) Pregunta a tus compañeros de clase cuántas horas duermen al día.
#
# b) Calcula la media y la desviación estándar poblacionales, considerando a todos tus compañeros de clase.
#
# c) ¿Qué porcentaje de tus compañeros duermen menos de seis horas?
#
# d) ¿Debajo de qué valor se encuentra el 10% de los que menos horas duermen?

# %% [markdown]
# # Ejercicio 13: Horas de Sueño
#
# La falta de sueño reparador puede afectar nuestra capacidad para llevar a cabo las actividades diarias, ya que estamos demasiado cansados o tenemos problemas de concentración. Todos los tipos de insomnio pueden llevar a somnolencia diurna, mala concentración e incapacidad para sentirnos renovados y descansados en la mañana.
#
# ## a) Pregunta a tus compañeros de clase cuántas horas duermen al día.
#
# - Este paso es empírico y depende de los datos que hayas recogido de tus compañeros de clase. Una vez que tengas esos datos, puedes calcular la **media** y la **desviación estándar**.
#
# ## b) Calcular la media y la desviación estándar poblacionales.
#
# La **media poblacional** $\mu$ y la **desviación estándar poblacional** $\sigma$ se calculan con las siguientes fórmulas:
#
# ### Media poblacional $\mu$:
#
# $$
# \mu = \frac{1}{N} \sum_{i=1}^{N} X_i
# $$
#
# Donde:
# - \(N\) es el número total de personas (el tamaño de la muestra o población).
# - \(X_i\) es el número de horas que duerme cada persona.
#
# ### Desviación estándar poblacional $\sigma$:
#
# $$
# \sigma = \sqrt{\frac{1}{N} \sum_{i=1}^{N} (X_i - \mu)^2}
# $$
#
# #### Ejemplo con datos:
# Supongamos que recopilaste las siguientes horas de sueño de 5 compañeros de clase: 5, 7, 6, 8, 5.
#
# 1. **Calcular la media**:
#    $$
#    \mu = \frac{1}{5} (5 + 7 + 6 + 8 + 5) = \frac{31}{5} = 6.2
#    $$
#
# 2. **Calcular la desviación estándar**:
#    - Primero, calculamos las diferencias al cuadrado respecto a la media:
#      $$
#      (5 - 6.2)^2 = 1.44, \quad (7 - 6.2)^2 = 0.64, \quad (6 - 6.2)^2 = 0.04, \quad (8 - 6.2)^2 = 3.24, \quad (5 - 6.2)^2 = 1.44
#      $$
#    - Sumamos los valores al cuadrado:
#      $$
#      1.44 + 0.64 + 0.04 + 3.24 + 1.44 = 6.8
#      $$
#    - Ahora calculamos la desviación estándar:
#      $$
#      \sigma = \sqrt{\frac{6.8}{5}} = \sqrt{1.36} \approx 1.167
#      $$
#
# Por lo tanto, la media es \(6.2\) horas y la desviación estándar es aproximadamente \(1.167\) horas.
#
# ## c) ¿Qué porcentaje de tus compañeros duermen menos de seis horas?
#
# Para calcular el porcentaje de compañeros que duermen menos de seis horas, utilizamos la **distribución normal**. Para esto, necesitamos el valor de \(Z\) correspondiente a las horas de sueño \(X = 6\), usando la fórmula de transformación estándar:
#
# $$
# Z = \frac{X - \mu}{\sigma}
# $$
#
# Sustituyendo los valores conocidos:
#
# $$
# Z = \frac{6 - 6.2}{1.167} = \frac{-0.2}{1.167} \approx -0.171
# $$
#
# - Usamos la tabla de la distribución normal estándar o una calculadora para encontrar el valor acumulado para \(Z = -0.171\). Este valor es aproximadamente \(P(Z \leq -0.171) \approx 0.432\).
#
# Por lo tanto, el porcentaje de compañeros que duermen menos de seis horas es aproximadamente:
#
# $$
# \text{Porcentaje} \approx 43.2\%
# $$
#
# ## d) ¿Debajo de qué valor se encuentra el 10\% de los que menos horas duermen?
#
# Para encontrar el valor debajo del cual se encuentra el 10\% de los compañeros que duermen menos horas, buscamos el valor de \(Z\) correspondiente al percentil 10. El valor de \(Z\) para el 10\% en la distribución normal es aproximadamente **-1.28**.
#
# Usamos la fórmula de transformación para despejar \(X\):
#
# $$
# Z = \frac{X - \mu}{\sigma}
# $$
#
# Sustituyendo \(Z = -1.28\), \($\mu$ = 6.2\) y \($\sigma$ = 1.167\):
#
# $$
# -1.28 = \frac{X - 6.2}{1.167}
# $$
#
# Despejamos \(X\):
#
# $$
# X = -1.28 \times 1.167 + 6.2 = -1.493 + 6.2 \approx 4.71
# $$
#
# Por lo tanto, el valor debajo del cual se encuentra el 10\% de los compañeros que duermen menos horas es aproximadamente:
#
# $$
# X \approx 4.71 \text{ horas}
# $$
#
# ---
#
# ### Resumen:
#
# a) Pregunta a tus compañeros de clase cuántas horas duermen al día. (Este paso es empírico y depende de los datos que hayas recogido).
#
# b) La **media** (\(\mu\)) es \(6.2\) horas y la **desviación estándar** (\(\sigma\)) es aproximadamente \(1.167\) horas.
#
# c) El **porcentaje** de compañeros que duermen menos de 6 horas es aproximadamente **43.2\%**.
#
# d) El valor debajo del cual se encuentra el **10\%** de los compañeros que duermen menos horas es **4.71 horas**.

# %%
import numpy as np
import scipy.stats as stats

# Datos
horas_sueño = [7, 8, 6, 5, 7, 9, 5, 6, 8, 7, 5, 6, 8, 6, 5]

# Cálculos
media = np.mean(horas_sueño)
desviacion_estandar = np.std(horas_sueño, ddof=1)  # Usar ddof=1 para una muestra

# Cálculo del porcentaje de compañeros que duermen menos de 6 horas
porcentaje_menos_6 = stats.norm.cdf(6, loc=media, scale=desviacion_estandar) * 100

# Cálculo del valor del percentil 10
valor_10_percentil = stats.norm.ppf(0.10, loc=media, scale=desviacion_estandar)

# Imprimir resultados
print(f"Media de horas de sueño: {media:.2f} horas")
print(f"Desviación estándar de horas de sueño: {desviacion_estandar:.2f} horas")
print(f"Porcentaje de compañeros que duermen menos de 6 horas: {porcentaje_menos_6:.2f}%")
print(f"Valor debajo del cual se encuentra el 10% de los que menos duermen: {valor_10_percentil:.2f} horas")
# Out:
# Media de horas de sueño: 6.53 horas
# Desviación estándar de horas de sueño: 1.30 horas
# Porcentaje de compañeros que duermen menos de 6 horas: 34.10%
# Valor debajo del cual se encuentra el 10% de los que menos duermen: 4.86 horas

# %% [markdown]
# ### Ejercicio 14:
# El cociente intelectual (iq) es la puntuación obtenida en tests que que permiten medir la inteligencia de una persona. Si los puntajes del cociente intelectual se distribuyen normalmente con media igual a 100, determina:
#
# a) La desviación estándar, si se sabe que el 2% se consideran personas superdotadas al tener un puntaje mayor a 130.
#
# b) ¿Cuál es la probabilidad de que una persona tenga un puntaje por debajo de 70 (retardo mental)?
#
# c) ¿Qué proporción de la población se le considera “genio”? Una persona que obtiene un puntaje de 165 o mayor es generalmente considerada genio.

# %% [markdown]
# # Problema de Cociente Intelectual (IQ)
#
# Sabemos que el cociente intelectual (IQ) de las personas sigue una distribución normal con media \(\mu = 100\). A continuación, resolveremos los problemas relacionados con esta distribución.
#
# ## a) Calcular la desviación estándar si el 2\% de las personas tienen un puntaje mayor a 130 (se consideran superdotados).
#
# - El 2\% de las personas tienen un puntaje mayor a 130. Esto implica que el área a la derecha de \(X = 130\) es 0.02.
# - Por lo tanto, el área acumulada a la izquierda de \(X = 130\) es \(1 - 0.02 = 0.98\).
# - Buscamos en la tabla de la distribución normal estándar el valor de \(Z\) correspondiente a una probabilidad acumulada de 0.98. Este valor es aproximadamente \(Z = 2.05\).
# - Usamos la fórmula de transformación para obtener la desviación estándar \(\sigma\):
#
# $$Z = \frac{X - \mu}{\sigma}$$
#
# Sustituyendo los valores conocidos:
#
# $$
# 2.05 = \frac{130 - 100}{\sigma}
# $$
#
# Despejando \(\sigma\):
#
# $$
# \sigma = \frac{30}{2.05} \approx 14.63
# $$
#
# Por lo tanto, la desviación estándar es aproximadamente
# $$ \sigma \approx 14.63 $$
#
# ## b) Calcular la probabilidad de que una persona tenga un puntaje por debajo de 70 (retardo mental).
#
# - Usamos la fórmula de transformación para convertir el puntaje $$X = 70$$ a la variable estánda $$Z:$$
#
#
# $$Z = \frac{X - \mu}{\sigma} = \frac{70 - 100}{14.63} = \frac{-30}{14.63} \approx -2.05$$
#
#
# - Buscamos en la tabla de la distribución normal estándar el valor correspondiente a $$Z = -2.05$$  Este valor es aproximadamente $$P(Z \leq -2.05) = 0.02\$$
#
# Por lo tanto, la probabilidad de que una persona tenga un puntaje por debajo de 70 es:
#
#
# $$P(X < 70) \approx 0.02$$
#
#
# Esto significa que el 2\% de la población tiene un puntaje inferior a 70.
#
# ## c) ¿Qué proporción de la población se le considera "genio"? Una persona con un puntaje de 165 o mayor es generalmente considerada genio.
#
# - Usamos la fórmula de transformación para convertir el puntaje \(X = 165\) a la variable estándar \(Z\):
#
#
# $$Z = \frac{X - \mu}{\sigma} = \frac{165 - 100}{14.63} = \frac{65}{14.63} \approx 4.44$$
#
#
# - Buscamos en la tabla de la distribución normal estándar el valor correspondiente a \(Z = 4.44\). Este valor es muy cercano a 1, lo que indica que la probabilidad acumulada es prácticamente 1.
# - La probabilidad de que una persona tenga un puntaje de 165 o mayor es:
#
#
# $$P(X \geq 165) = 1 - P(Z \leq 4.44) = 1 - 0.99999 = 0.00001$$
#
#
# Por lo tanto, la proporción de la población considerada genio (puntaje \(\geq 165\)) es aproximadamente \(0.00001\%\).

# %% [markdown]
# ### Pasos para resolver este ejercicio:
#
#
# a) Desviación estándar:
# Sabemos que el cociente intelectual sigue una distribución normal con una media μ=100, y que el 2% de las personas tienen un puntaje mayor a 130, lo que corresponde al 98% en la cola izquierda de la distribución normal.
#
# El puntaje de 130 está en el percentil 98. Para determinar la desviación estándar (𝜎), podemos usar la fórmula de la distribución normal estándar:
#
# $$Z = \frac{X - \mu}{\sigma}$$
# ​
# Donde: Z es el valor crítico para el percentil 98 (usaremos una tabla de la distribución normal estándar o una función de Python para encontrarlo), X=130 es el puntaje de cociente intelectual, μ=100 es la media.
#
# Parte b) Probabilidad de tener un puntaje por debajo de 70:
# La probabilidad de que una persona tenga un puntaje por debajo de 70 se puede encontrar utilizando la fórmula de la distribución normal estándar. Se necesita calcular el valor 𝑍 para X=70 y luego usarlo para obtener la probabilidad asociada.
#
# Parte c) Proporción de la población con un puntaje de 165 o mayor:
# Para encontrar la proporción de personas con un puntaje de 165 o mayor, se calcula el valor
# Z correspondiente a X=165 y luego se determina la probabilidad asociada con ese valor.

# %%
import scipy.stats as stats

# Función para calcular la desviación estándar
def calcular_desviacion_estandar(media, puntaje_superdotado, percentil):
    # Calculamos el valor Z correspondiente al percentil
    Z = stats.norm.ppf(percentil, loc=media, scale=1)
    # Desviación estándar es (X - media) / Z
    desviacion_estandar = (puntaje_superdotado - media) / (Z - media)
    return desviacion_estandar

# Función para calcular la probabilidad de puntaje por debajo de un valor
def probabilidad_por_bajo(puntaje, media, desviacion_estandar):
    return stats.norm.cdf(puntaje, loc=media, scale=desviacion_estandar)

# Función para calcular la probabilidad de puntaje mayor o igual a un valor
def probabilidad_por_encima(puntaje, media, desviacion_estandar):
    return 1 - stats.norm.cdf(puntaje, loc=media, scale=desviacion_estandar)

# Parámetros del problema
media = 100
puntaje_superdotado = 130
puntaje_bajo = 70
puntaje_genio = 165
percentil = 0.98  # El 98% de las personas están por debajo de 130

# Parte a) Calcular la desviación estándar
desviacion_estandar = calcular_desviacion_estandar(media, puntaje_superdotado, percentil)

# Parte b) Calcular la probabilidad de puntaje por debajo de 70
probabilidad_bajo_70 = probabilidad_por_bajo(puntaje_bajo, media, desviacion_estandar)

# Parte c) Calcular la probabilidad de puntaje mayor o igual a 165
probabilidad_mayor_165 = probabilidad_por_encima(puntaje_genio, media, desviacion_estandar)

# Imprimir resultados
print(f"Desviación estándar: {desviacion_estandar:.2f}")
print(f"Probabilidad de puntaje por debajo de 70: {probabilidad_bajo_70:.4f}")
print(f"Proporción de personas consideradas 'genio' (puntaje >= 165): {probabilidad_mayor_165:.8f}")
# Out:
# Desviación estándar: 14.61
# Probabilidad de puntaje por debajo de 70: 0.0200
# Proporción de personas consideradas 'genio' (puntaje >= 165): 0.00000430

# %% [markdown]
# ### Ejercicio 15:
# Johnny Depp es uno de los mejores actores de Hollywood y en 2010 fue considerado el hombre más sexy. Ha trabajado en más de cuarenta películas. Si la duración de sus filmes sigue una distribución normal con una media de 112.5111 minutos y una varianza de 383.8054, calcula:
#
# a) La probabilidad de que una película dure menos de 90 minutos.
#
# b) La probabilidad de que una película dure entre 95 y 125 minutos.
#
# c) La probabilidad de que dure más de 150 minutos.

# %% [markdown]
# ### Pasos para resolver este ejercicio:
# Datos del problema:
# Media (𝜇) = 112.5111 minutos
#
# Varianza ($𝜎^2$): 383.8054
#
# Desviación estándar (𝜎): $\sqrt{\text{Varianza}} = \sqrt{383.8054}$
#
# Fórmulas clave:
#
# Utilizamos la distribución normal estándar para calcular probabilidades. La fórmula de estandarización es:
#
# $$Z = \frac{X - \mu}{\sigma}$$
#
# Con Z, calculamos las probabilidades con las funciones acumuladas $1−norm.cdf(Z)$, según corresponda.
#
# ----
#
# a) Probabilidad de que una película dure menos de 90 minutos:
#
# $$P(X≤90)$$
#
# - Convertimos X=90 a un valor 𝑍:
#
# $$Z = \frac{90 - \mu}{\sigma}$$
#
# Calculamos P(X≤90) usando la función acumulada $norm.cdf(Z)$.
#
# ----
#
# b) Probabilidad de que una película dure entre 95 y 125 minutos:
#
# $$P(95≤X≤125)=P(X≤125)−P(X≤95)$$
#
# - Convertimos 𝑋=95 y 𝑋=125 a sus valores correspondientes de 𝑍:
#
# $$Z_{95} = \frac{95 - \mu}{\sigma}, \quad Z_{125} = \frac{125 - \mu}{\sigma}$$
#
# - Calculamos ambas probabilidades acumuladas y hacemos la resta:
#
# $$P(95≤X≤125)=norm.cdf(Z_{125})−norm.cdf(Z_{95})$$
#
# ---
#
# c) Probabilidad de que una película dure más de 150 minutos:
#
# $$P(X≥150)=1−P(X≤150)$$
#
# Convertimos X=150 a Z:
# ​
# $$Z = \frac{150 - \mu}{\sigma}$$
#
# Calculamos $P(X≤150)$ con $norm.cdf(Z)$ y restamos de 1.

# %%
import scipy.stats as stats
import numpy as np

media = 112.5111
varianza = 383.8054
desviacion_estandar = np.sqrt(varianza)

probabilidad_menos_90 = stats.norm.cdf(90, loc=media, scale=desviacion_estandar)

probabilidad_entre_95_y_125 = stats.norm.cdf(125, loc=media, scale=desviacion_estandar) - stats.norm.cdf(95, loc=media, scale=desviacion_estandar)

probabilidad_mas_150 = 1 - stats.norm.cdf(150, loc=media, scale=desviacion_estandar)

# Imprimir resultados
print(f"Probabilidad de que una película dure menos de 90 minutos: {probabilidad_menos_90:.4f}")
print(f"Probabilidad de que una película dure entre 95 y 125 minutos: {probabilidad_entre_95_y_125:.4f}")
print(f"Probabilidad de que una película dure más de 150 minutos: {probabilidad_mas_150:.4f}")
# Out:
# Probabilidad de que una película dure menos de 90 minutos: 0.1253
# Probabilidad de que una película dure entre 95 y 125 minutos: 0.5524
# Probabilidad de que una película dure más de 150 minutos: 0.0278

# %% [markdown]
# ### Ejercicio 16:
# Cualquier tipo de mascota requiere cuidados y tiempo, además de que implica gastos de alimentación y salud, entre otros. Por ello, se debe ser consciente al tener una mascota; por ejemplo, un perro. De acuerdo con las estadísticas de refugios para perros callejeros, ocho de cada 10 perros que se compran terminan en la calle. Esto representa no sólo un problema de salud sino de falta de responsabilidad por parte del dueño. Si en el mes siguiente se venden 50 perros, determina, utilizando la aproximación a la normal:
#
# a) ¿Cuál es la probabilidad de que menos de 30 perros terminen en la calle?
#
# b) ¿Cuál es la probabilidad de que entre 30 y 45 perros terminen en la calle?

# %% [markdown]
# ### Pasos para resolver este ejercicio:
#
# Datos del problema:
#
# $n=50$ : Número total de perros vendidos.
#
# $𝑝=0.8$: Probabilidad de que un perro termine en la calle.
#
# $q=1−p=0.2$: Probabilidad de que un perro no termine en la calle.
#
# Media (𝜇) y desviación estándar (𝜎) de la distribución binomial:
#
# $$\mu = n \cdot p, \quad \sigma = \sqrt{n \cdot p \cdot q}$$
#
# Fórmulas clave para la aproximación normal:
#
# Utilizamos la distribución normal con media 𝜇 y desviación estándar 𝜎 para aproximar la binomial. Aplicaremos la corrección por continuidad, sumando o restando 0.5 a los valores enteros.
#
# $$Z = \frac{X - \mu}{\sigma}$$
#
# ---
#
# a) Probabilidad de que menos de 30 perros terminen en la calle:
#
# Esto se traduce en: $$𝑃(𝑋<30)$$
#
# - Calculamos la media y la desviación estándar:
#
# $$\mu = 50 \cdot 0.8 = 40, \quad \sigma = \sqrt{50 \cdot 0.8 \cdot 0.2} \approx 2.828$$
#
# - Aplicamos la corrección por continuidad $(𝑋=29.5)$:
#
# $$Z = \frac{29.5 - 40}{\sigma} = \frac{29.5 - 40}{2.828} \approx -3.71$$
#
# - Calculamos $𝑃(𝑋<30)$ usando la función acumulada de la distribución normal:
#
# $$P(X<30)=norm.cdf(−3.71)$$
#
# ---
#
# b) Probabilidad de que entre 30 y 45 perros terminen en la calle:
# Esto se traduce en:
#
# $$P(30≤X≤45)$$
#
# Aplicamos la corrección por continuidad:
#
# $$P(30≤X≤45)=P(X≤45.5)−P(X≤29.5)$$
#
# Calculamos los valores de 𝑍:
#
# Para $X=45.5$:
#
# $$Z = \frac{45.5 - 40}{\sigma} = \frac{45.5 - 40}{2.828} \approx 1.95$$
#
# Para 𝑋=29.5 (calculado antes):
#
# $$Z≈−3.71$$
# Calculamos las probabilidades acumuladas:
# $$P(30≤X≤45)=norm.cdf(1.95)−norm.cdf(−3.71)$$

# %%
import scipy.stats as stats
import numpy as np

n = 50  # Número de perros vendidos
p = 0.8  # Probabilidad de que un perro termine en la calle
q = 1 - p  # Probabilidad de que un perro no termine en la calle

media = n * p
desviacion_estandar = np.sqrt(n * p * q)

probabilidad_menos_30 = stats.norm.cdf(30, loc=media, scale=desviacion_estandar)

probabilidad_entre_30_y_45 = stats.norm.cdf(45, loc=media, scale=desviacion_estandar) - stats.norm.cdf(30, loc=media, scale=desviacion_estandar)

# Imprimir resultados
print(f"Probabilidad de que menos de 30 perros terminen en la calle: {probabilidad_menos_30:.4f}")
print(f"Probabilidad de que entre 30 y 45 perros terminen en la calle: {probabilidad_entre_30_y_45:.4f}")
# Out:
# Probabilidad de que menos de 30 perros terminen en la calle: 0.0002
# Probabilidad de que entre 30 y 45 perros terminen en la calle: 0.9612

# %% [markdown]
# ### Ejercicio 17:
#
# En México hay dos grandes empresas de televisión abierta: Televisa y TV Azteca. Se sabe que TV Azteca tiene aproximadamente 40% de la audiencia. Si se realiza una encuesta a 100 personas, usando la aproximación de la normal, determina:
#
# a) La probabilidad de que más de 55 personas vean TV Azteca.
#
# b) La probabilidad de que menos de 30 personas sintonicen TV Azteca.

# %% [markdown]
# ### Pasos para resolver este ejercicio:
#
# Datos iniciales:
#
# - $n=100$
#
# - $p=0.4$
#
# - $q=1−p=0.6$
#
# Media (𝜇) y desviación estándar (𝜎) de la distribución binomial:
#
# $$\mu = n \cdot p, \quad \sigma = \sqrt{n \cdot p \cdot q}$$
#
# Fórmulas clave para la aproximación normal:
#
# Utilizamos la distribución normal con media 𝜇 y desviación estándar 𝜎 para aproximar la binomial. Aplicaremos la corrección por continuidad, sumando o restando 0.5 a los valores enteros.
#
# $$Z = \frac{X - \mu}{\sigma}$$
#
# Y aplicamos la corrección por continuidad, ajustando los límites $𝑋±0.5$.
#
# ---
#
# a) Probabilidad de que más de 55 personas vean TV Azteca:
#
# $$P(X>55)=P(X≥56)$$
#
# Calculamos la media y la desviación estándar:
#
# $$\mu = 100 \cdot 0.4 = 40, \quad \sigma = \sqrt{100 \cdot 0.4 \cdot 0.6} \approx \sqrt{24} \approx 4.899$$
#
# Aplicamos la corrección por continuidad:
#
# $$P(X>55)=P(X≥55.5)$$
#
# Convertimos a 𝑍:
#
# $$Z = \frac{55.5 - 40}{\sigma} = \frac{55.5 - 40}{4.899} \approx 3.17$$
#
# Usamos la función acumulada de la normal estándar:
#
# $$P(X>55)=1−P(Z≤3.17)=1−norm.cdf(3.17)$$
#
# ---
#
# b) Probabilidad de que menos de 30 personas sintonicen TV Azteca:
#
# $$P(X<30)=P(X≤29)$$
#
# Aplicamos la corrección por continuidad:
#
# $$P(X<30)=P(X≤29.5)$$
#
# Convertimos a 𝑍:
#
# $$Z = \frac{29.5 - 40}{\sigma} = \frac{29.5 - 40}{4.899} \approx -2.14$$
#
# Usamos la función acumulada de la normal estándar:
#
# $$P(X<30)=P(Z≤−2.14)=norm.cdf(−2.14)$$

# %%
import scipy.stats as stats
import numpy as np

n = 100  # Número de personas encuestadas
p = 0.40  # Probabilidad de que una persona vea TV Azteca
q = 1 - p  # Probabilidad de que una persona no vea TV Azteca

media = n * p
desviacion_estandar = np.sqrt(n * p * q)

probabilidad_mas_55 = 1 - stats.norm.cdf(55, loc=media, scale=desviacion_estandar)

probabilidad_menos_30 = stats.norm.cdf(30, loc=media, scale=desviacion_estandar)

# Imprimir resultados
print(f"Probabilidad de que más de 55 personas vean TV Azteca: {probabilidad_mas_55:.4f}")
print(f"Probabilidad de que menos de 30 personas vean TV Azteca: {probabilidad_menos_30:.4f}")
# Out:
# Probabilidad de que más de 55 personas vean TV Azteca: 0.0011
# Probabilidad de que menos de 30 personas vean TV Azteca: 0.0206
